# %%
print(3+4)
print(5-2)
print(3*2)
print(4/2)
print(5**2)
# Out:
# 7
# 3
# 6
# 2.0
# 25

# %%
print(5//2)
# Out:
# 2

# %%
#par ou impar com resto de divisão

if 5%2 == 0:
    print("par")
else:
    print("impar")
# Out:
# par
