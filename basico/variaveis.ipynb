# %%
x = 2
y = 4
z = 5

# %%
print(x)
# Out:
# 2

# %%
print(x+y+z)
# Out:
# 11

# %%
print(y/x)
# Out:
# 2.0

# %%
x == 2
# Out:
# False

# %%
x == 3
# Out:
# False

# %%
var1 = 10
var2 = 10.5

# %%
print(type(var1),type(var2))
# Out:
# <class 'int'> <class 'float'>

# %%
oi = "olá"
print(oi)
# Out:
# olá

# %%
type(oi)
# Out:
# str
